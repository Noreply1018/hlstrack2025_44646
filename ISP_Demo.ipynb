# %% [markdown]
# <div style="
#     background: linear-gradient(120deg,#4da3ff,#00c6ff);
#     border-radius: 22px;
#     padding: 30px 36px 24px 36px;
#     color: #ffffff;
#     box-shadow: 0 12px 28px rgba(0,0,0,0.18);
#     font-family: -apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif;
#     line-height: 1.4;
# ">
#
#   <!-- 主标题 -->
#   <div style="font-size: 38px; font-weight: 800; letter-spacing: 1px; margin-bottom: 6px;">
#     🎬 FPGA ISP 影像工作台
#   </div>
#
#   <!-- 副标题 -->
#   <div style="font-size: 17px; opacity: 0.96; margin-bottom: 14px;">
#     静态剧照 & 实时调色 · 基于 PYNQ-Z2 的软硬核协同演示
#   </div>
#
#   <!-- 分割线 -->
#   <div style="height:1px; background:rgba(255,255,255,0.55); margin: 8px 0 14px 0;"></div>
#
#   <!-- 比赛信息 -->
#   <div style="display:flex; flex-wrap:wrap; gap:10px; font-size: 13px; margin-bottom: 4px;">
#     <div style="padding:4px 10px; border-radius:999px; background:rgba(0,0,0,0.12);">🏆 AMD 命题式基础能力赛道</div>
#     <div style="padding:4px 10px; border-radius:999px; background:rgba(0,0,0,0.12);">👥 队伍名：让我们凡思逸下</div>
#     <div style="padding:4px 10px; border-radius:999px; background:rgba(0,0,0,0.12);">🔢 队伍编号：44646</div>
#   </div>
#
#   <div style="font-size: 13px; opacity: 0.95; margin-top: 4px;">队伍成员：胡凯锋、李逸凡</div>
#
#   <!-- 标签区 -->
#   <div style="display:flex; flex-wrap:wrap; gap:8px; font-size:12px; margin-top:12px;">
#     <span style="padding:4px 9px; border-radius:999px; background:rgba(255,255,255,0.18);">⚙️ FPGA ISP 加速</span>
#     <span style="padding:4px 9px; border-radius:999px; background:rgba(255,255,255,0.18);">🖥️ HDMI Out 实时画面</span>
#     <span style="padding:4px 9px; border-radius:999px; background:rgba(255,255,255,0.18);">📊 Jupyter 交互参数控制</span>
#   </div>
#
# </div>

# %% [markdown]
# <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#
# <!-- 项目简介 -->
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 20px 25px; border-radius: 16px; margin: 20px 0;">
#   <div style="font-size: 22px; font-weight: 700; margin-bottom: 10px;">📋 项目概述</div>
#   <div style="font-size: 14px; line-height: 1.8; opacity: 0.95;">
#     本项目搭建了一套面向展示的 <b>FPGA + CPU 协同 ISP 影像工作台</b>：
#     <div style="margin-top: 8px; margin-left: 10px;">
#       • 在 <b>静态剧照区</b>，用 CPU 作为黄金参考，对比 FPGA 硬核的画质与性能；<br>
#       • 在 <b>视频导演区</b>，通过实时 ISP + 调色时间轴，展示软硬核在 720p 视频下的帧率与并行优势。
#     </div>
#   </div>
# </div>
#
# <!-- 目录导航 -->
# <div style="background: #f8f9fa; border-radius: 12px; padding: 20px; margin: 15px 0; border: 1px solid #e9ecef;">
#   <div style="font-size: 18px; font-weight: 700; color: #2c3e50; margin-bottom: 15px;">📑 目录导航</div>
#
#   <!-- 第一部分：静态图 -->
#   <div style="font-size: 14px; font-weight: 600; color: #667eea; margin: 15px 0 10px 0;">📷 第一部分：静态剧照区</div>
#   <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(280px, 1fr)); gap: 12px;">
#     <div style="background: white; padding: 12px 16px; border-radius: 10px; border-left: 4px solid #3498db; box-shadow: 0 2px 8px rgba(0,0,0,0.06);">
#       <div style="font-weight: 600; color: #3498db;">1-1 静态剧照 · ISP 调色台</div>
#       <div style="font-size: 12px; color: #666; margin-top: 4px;">可选模式 + 拉条调参，软核/硬核切换统一风格</div>
#     </div>
#     <div style="background: white; padding: 12px 16px; border-radius: 10px; border-left: 4px solid #e74c3c; box-shadow: 0 2px 8px rgba(0,0,0,0.06);">
#       <div style="font-weight: 600; color: #e74c3c;">1-2 静态评测 · 加速计时器</div>
#       <div style="font-size: 12px; color: #666; margin-top: 4px;">多轮重复测试，用数字量化 FPGA vs CPU 的静态加速比</div>
#     </div>
#     <div style="background: white; padding: 12px 16px; border-radius: 10px; border-left: 4px solid #27ae60; box-shadow: 0 2px 8px rgba(0,0,0,0.06);">
#       <div style="font-weight: 600; color: #27ae60;">1-3 静态评测 · 画质对对碰</div>
#       <div style="font-size: 12px; color: #666; margin-top: 4px;">用 PSNR/SSIM/MAE 给软核 vs 硬核打分，验证算法还原度</div>
#     </div>
#     <div style="background: white; padding: 12px 16px; border-radius: 10px; border-left: 4px solid #9b59b6; box-shadow: 0 2px 8px rgba(0,0,0,0.06);">
#       <div style="font-weight: 600; color: #9b59b6;">1-4 静态评测 · 硬核效果放大镜</div>
#       <div style="font-size: 12px; color: #666; margin-top: 4px;">聚焦 FPGA 硬核 5 级流水线，Gamma 曲线和直方图变化</div>
#     </div>
#     <div style="background: white; padding: 12px 16px; border-radius: 10px; border-left: 4px solid #f39c12; box-shadow: 0 2px 8px rgba(0,0,0,0.06);">
#       <div style="font-weight: 600; color: #f39c12;">1-5 静态评测 · 并行心电图</div>
#       <div style="font-size: 12px; color: #666; margin-top: 4px;">像素级流水线让 ISP 延时保持"心电图水平线"</div>
#     </div>
#   </div>
#
#   <!-- 第二部分：视频 -->
#   <div style="font-size: 14px; font-weight: 600; color: #e74c3c; margin: 20px 0 10px 0;">🎬 第二部分：视频导演区</div>
#   <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(280px, 1fr)); gap: 12px;">
#     <div style="background: white; padding: 12px 16px; border-radius: 10px; border-left: 4px solid #1a1a2e; box-shadow: 0 2px 8px rgba(0,0,0,0.06);">
#       <div style="font-weight: 600; color: #1a1a2e;">2-1 导演调色台 · 视频风格时间轴</div>
#       <div style="font-size: 12px; color: #666; margin-top: 4px;">关键帧 + 自动插值，形成"调色脚本"</div>
#     </div>
#     <div style="background: white; padding: 12px 16px; border-radius: 10px; border-left: 4px solid #e74c3c; box-shadow: 0 2px 8px rgba(0,0,0,0.06);">
#       <div style="font-weight: 600; color: #e74c3c;">2-2 视频跑分台 · 帧率与吞吐对对碰</div>
#       <div style="font-size: 12px; color: #666; margin-top: 4px;">CPU 只能当 PPT，FPGA 才是真实时</div>
#     </div>
#     <div style="background: white; padding: 12px 16px; border-radius: 10px; border-left: 4px solid #9b59b6; box-shadow: 0 2px 8px rgba(0,0,0,0.06);">
#       <div style="font-weight: 600; color: #9b59b6;">2-3 并行实验室 · 让硬核帮软核瘦身</div>
#       <div style="font-size: 12px; color: #666; margin-top: 4px;">ISP offload 到 FPGA，CPU 还能干别的</div>
#     </div>
#     <div style="background: white; padding: 12px 16px; border-radius: 10px; border-left: 4px solid #00b894; box-shadow: 0 2px 8px rgba(0,0,0,0.06);">
#       <div style="font-weight: 600; color: #00b894;">2-4 AI 场记机 · 场景识别导演助理</div>
#       <div style="font-size: 12px; color: #666; margin-top: 4px;">轻量级神经网络实时识别场景，自动切换 ISP 模式</div>
#     </div>
#   </div>
# </div>
#
# <!-- 系统数据流 - 新样式 -->
# <div style="background: linear-gradient(135deg, #f5f7fa 0%, #e4e8f0 100%); border-radius: 20px; padding: 24px 32px; color: #2c3e50; box-shadow: 0 8px 24px rgba(0,0,0,0.1); line-height: 1.4; margin: 15px 0; border: 1px solid #dde4ec;">
#   <div style="display: flex; align-items: center; gap: 8px; margin-bottom: 20px;">
#     <div style="font-size: 20px;">📡</div>
#     <div style="font-size: 18px; font-weight: 700; color: #2c3e50;">系统数据流</div>
#   </div>
#
#   <!-- 主数据流 - 更宽松的布局 -->
#   <div style="display: flex; align-items: center; justify-content: center; gap: 24px; flex-wrap: wrap; margin-bottom: 20px;">
#     <div style="min-width: 110px; background: linear-gradient(135deg, #3498db, #2980b9); border-radius: 16px; padding: 16px 18px; text-align: center; color: white; box-shadow: 0 4px 12px rgba(52,152,219,0.3);">
#       <div style="font-size: 26px; margin-bottom: 6px;">🖼️</div>
#       <div style="font-size: 14px; font-weight: 600;">图片文件</div>
#       <div style="font-size: 10px; opacity: 0.9;">SD卡/本地</div>
#     </div>
#     <div style="font-size: 28px; color: #667eea;">→</div>
#     <div style="min-width: 110px; background: linear-gradient(135deg, #9b59b6, #8e44ad); border-radius: 16px; padding: 16px 18px; text-align: center; color: white; box-shadow: 0 4px 12px rgba(155,89,182,0.3);">
#       <div style="font-size: 26px; margin-bottom: 6px;">💾</div>
#       <div style="font-size: 14px; font-weight: 600;">DDR 缓冲</div>
#       <div style="font-size: 10px; opacity: 0.9;">PS/PL共享</div>
#     </div>
#     <div style="font-size: 28px; color: #667eea;">→</div>
#     <div style="min-width: 110px; background: linear-gradient(135deg, #f1c40f, #e67e22); border-radius: 16px; padding: 16px 18px; text-align: center; color: white; box-shadow: 0 4px 12px rgba(241,196,15,0.3);">
#       <div style="font-size: 26px; margin-bottom: 6px;">📤</div>
#       <div style="font-size: 14px; font-weight: 600;">VDMA</div>
#       <div style="font-size: 10px; opacity: 0.9;">AXI-Stream</div>
#     </div>
#     <div style="font-size: 28px; color: #667eea;">→</div>
#     <div style="min-width: 110px; background: linear-gradient(135deg, #2ecc71, #27ae60); border-radius: 16px; padding: 16px 18px; text-align: center; color: white; box-shadow: 0 4px 12px rgba(46,204,113,0.3);">
#       <div style="font-size: 26px; margin-bottom: 6px;">⚡</div>
#       <div style="font-size: 14px; font-weight: 600;">ISP 硬核</div>
#       <div style="font-size: 10px; opacity: 0.9;">FPGA PL</div>
#     </div>
#     <div style="font-size: 28px; color: #667eea;">→</div>
#     <div style="min-width: 110px; background: linear-gradient(135deg, #e74c3c, #c0392b); border-radius: 16px; padding: 16px 18px; text-align: center; color: white; box-shadow: 0 4px 12px rgba(231,76,60,0.3);">
#       <div style="font-size: 26px; margin-bottom: 6px;">📺</div>
#       <div style="font-size: 14px; font-weight: 600;">HDMI Out</div>
#       <div style="font-size: 10px; opacity: 0.9;">显示器</div>
#     </div>
#   </div>
#
#   <!-- 分割线 -->
#   <div style="height: 1px; background: linear-gradient(to right, transparent, #bdc3c7, transparent); margin: 16px 0;"></div>
#
#   <!-- 第二行：反馈路径 -->
#   <div style="display: flex; align-items: center; justify-content: center; gap: 20px; flex-wrap: wrap; font-size: 13px;">
#     <div style="background: linear-gradient(135deg, #f39c12, #d35400); padding: 10px 18px; border-radius: 10px; color: #fff; font-weight: 600; box-shadow: 0 3px 10px rgba(243,156,18,0.3);">📁 捕获回 DDR</div>
#     <div style="font-size: 24px; color: #667eea;">→</div>
#     <div style="background: #fff; padding: 10px 18px; border-radius: 10px; color: #2c3e50; font-weight: 500; border: 2px solid #667eea; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">🖥️ Notebook 预览</div>
#     <div style="font-size: 24px; color: #667eea;">→</div>
#     <div style="background: linear-gradient(135deg, #2ecc71, #27ae60); padding: 10px 18px; border-radius: 10px; color: #fff; font-weight: 600; box-shadow: 0 3px 10px rgba(46,204,113,0.3);">📺 HDMI 实时</div>
#     <div style="font-size: 24px; color: #667eea;">→</div>
#     <div style="background: #fff; padding: 10px 18px; border-radius: 10px; color: #2c3e50; font-weight: 500; border: 2px solid #e74c3c; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">👀 评委画面</div>
#   </div>
#
#   <!-- 图例 -->
#   <div style="display: flex; justify-content: center; gap: 24px; margin-top: 18px; font-size: 12px; color: #666;">
#     <span style="display: flex; align-items: center; gap: 4px;"><span style="width: 10px; height: 10px; background: #3498db; border-radius: 50%;"></span> PS (ARM)</span>
#     <span style="display: flex; align-items: center; gap: 4px;"><span style="width: 10px; height: 10px; background: #2ecc71; border-radius: 50%;"></span> PL (FPGA)</span>
#     <span style="display: flex; align-items: center; gap: 4px;"><span style="width: 10px; height: 10px; background: #f39c12; border-radius: 50%;"></span> DMA</span>
#     <span style="display: flex; align-items: center; gap: 4px;"><span style="width: 10px; height: 10px; background: #e74c3c; border-radius: 50%;"></span> 视频</span>
#   </div>
# </div>
#
# <!-- Vitis 算子表格 -->
# <div style="background: white; border-radius: 12px; padding: 20px; margin: 15px 0; border: 1px solid #e9ecef;">
#   <div style="font-size: 18px; font-weight: 700; color: #2c3e50; margin-bottom: 15px;">⚙️ Vitis Vision Library 官方算子</div>
#   <div style="font-size: 13px; color: #666; margin-bottom: 15px; line-height: 1.6;">
#     本项目 ISP 硬核基于 <b>Xilinx Vitis Vision Library</b> 实现，共使用 <b>5 个官方算子</b>：
#   </div>
#   <table style="width: 100%; border-collapse: collapse; font-size: 13px;">
#     <thead>
#       <tr style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white;">
#         <th style="padding: 12px; text-align: center; width: 25%;">官方算子</th>
#         <th style="padding: 12px; text-align: center; width: 20%;">类型</th>
#         <th style="padding: 12px; text-align: center; width: 55%;">用途说明</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr style="background: #e3f2fd;">
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;"><code style="background:#1565c0; color:white; padding:4px 10px; border-radius:6px; font-weight:600;">xf::cv::Mat</code></td>
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;">📦 数据结构</td>
#         <td style="padding: 12px; text-align: left; border-bottom: 1px solid #eee;">Vitis Vision 核心数据容器，存储 8UC3 (24-bit RGB) 图像，支持流式读写</td>
#       </tr>
#       <tr style="background: #e8f5e9;">
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;"><code style="background:#2e7d32; color:white; padding:4px 10px; border-radius:6px; font-weight:600;">xf::cv::LUT</code></td>
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;">🌈 图像处理</td>
#         <td style="padding: 12px; text-align: left; border-bottom: 1px solid #eee;">256 条目查找表算子，用于 Block2 Gamma 校正，预计算 γ 曲线实现非线性映射</td>
#       </tr>
#       <tr style="background: #fff3e0;">
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;"><code style="background:#e65100; color:white; padding:4px 10px; border-radius:6px; font-weight:600;">xf::cv::GaussianBlur</code></td>
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;">🔇 图像处理</td>
#         <td style="padding: 12px; text-align: left; border-bottom: 1px solid #eee;">3×3 高斯模糊算子，用于 Block3 去噪滤波，内部使用 Line Buffer 实现</td>
#       </tr>
#       <tr style="background: #fce4ec;">
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;"><code style="background:#c2185b; color:white; padding:4px 10px; border-radius:6px; font-weight:600;">xf::cv::AXIvideo2xfMat</code></td>
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;">📥 接口转换</td>
#         <td style="padding: 12px; text-align: left; border-bottom: 1px solid #eee;">AXI-Stream 视频流 → xf::cv::Mat，将 VDMA 输入转换为内部数据格式</td>
#       </tr>
#       <tr style="background: #ede7f6;">
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;"><code style="background:#7b1fa2; color:white; padding:4px 10px; border-radius:6px; font-weight:600;">xf::cv::xfMat2AXIvideo</code></td>
#         <td style="padding: 12px; text-align: center; border-bottom: 1px solid #eee;">📤 接口转换</td>
#         <td style="padding: 12px; text-align: left; border-bottom: 1px solid #eee;">xf::cv::Mat → AXI-Stream 视频流，将处理结果输出到 HDMI 控制器</td>
#       </tr>
#     </tbody>
#   </table>
# </div>
#
# <!-- 软硬核对比卡片 -->
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(320px, 1fr)); gap: 20px; margin: 20px 0;">
#   <!-- 软核 -->
#   <div style="background: linear-gradient(135deg, #fff5f5 0%, #fed7d7 100%); border-radius: 16px; padding: 20px 24px; border-left: 5px solid #e74c3c;">
#     <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 15px;">
#       <span style="font-size: 24px;">💻</span>
#       <span style="font-size: 18px; font-weight: 700; color: #c0392b;">软核 (CPU)</span>
#     </div>
#     <div style="font-size: 13px; line-height: 2; color: #333;">
#       <div>• <b>处理器：</b>ARM Cortex-A9</div>
#       <div>• <b>实现方式：</b>Python + OpenCV</div>
#       <div>• <b>处理模式：</b>帧级批处理</div>
#     </div>
#   </div>
#
#   <!-- 硬核 -->
#   <div style="background: linear-gradient(135deg, #f0fff4 0%, #c6f6d5 100%); border-radius: 16px; padding: 20px 24px; border-left: 5px solid #27ae60;">
#     <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 15px;">
#       <span style="font-size: 24px;">⚡</span>
#       <span style="font-size: 18px; font-weight: 700; color: #27ae60;">硬核 (FPGA)</span>
#     </div>
#     <div style="font-size: 13px; line-height: 2; color: #333;">
#       <div>• <b>处理器：</b>Zynq-7020 PL</div>
#       <div>• <b>实现方式：</b>Vitis HLS + AXI-Stream</div>
#       <div>• <b>处理模式：</b>像素级流水线</div>
#     </div>
#   </div>
# </div>
#
# </div>

# %% [markdown]
# ---
#
# # ⚙️ 预处理：一键初始化
#
# 运行下方代码完成所有初始化（FPGA Overlay、ISP 模块、视频预加载与预热）

# %%
import sys
sys.path.insert(0, '../py')

from demo_preload import DemoPreloader

# 创建预处理器并运行
preloader = DemoPreloader()
preloader.run(
    load_video=True,
    video_file='all_720p_6fps_bgr.npy',
    verbose=True
)

# 额外预热：AI 智能导播模块（2-4-2 需要）
from scene_mlp_ui import warmup_ai_video
warmup_ai_video(preloader.hw_demo, preloader.player, verbose=True)

# %% [markdown]
# ---
#
# # 📷 第一部分：静态剧照区
#
# ---
#
# ## 1-1 静态剧照 · ISP 调色台
#
# 运行下方代码，打开 **静态剧照调色台**：
#
# - 选择不同预设模式（夜景 / 逆光 / 文档 / 风景）
# - 调节亮度、对比度、Gamma 等参数
# - 在同一张静态图上切换软核/硬核，实现"所见即所得"的效果预览

# %%
# 确保 ipywidgets 正确渲染
from IPython.display import display
import ipywidgets
ipywidgets.Widget.close_all()  # 清理旧的 widgets

from isp_ui import launch_isp_demo
# 使用预加载的组件
isp_demo_ui = launch_isp_demo(
    preloaded_hw=preloader.hw_demo,
    preloaded_soft=preloader.soft_demo
)
None  # 抑制自动输出

# %% [markdown]
# ---
#
# ## 1-2 静态评测 · 加速计时器
#
# 在相同分辨率和算法配置下，对多张静态图进行多轮重复测试，分别统计 CPU 软核和 FPGA 硬核的单帧处理时间：
#
# - 给出平均耗时和加速比
# - 展示"同样的 ISP 算法，硬核能快到什么程度"

# %%
from comparison_ui import launch_performance_comparison
perf_ui = launch_performance_comparison(preloader.soft_demo, preloader.hw_demo)
None  # 抑制自动输出

# %% [markdown]
# ---
#
# ## 1-3 静态评测 · 画质对对碰
#
# 将同一批测试图片分别送入 **CPU 软核 ISP** 和 **FPGA 硬核 ISP**，使用 PSNR / SSIM / MAE 等指标，定量评估二者输出的一致性：
#
# - 画面肉眼看起来是否一致？
# - 指标上，硬核是否足够接近黄金参考的软核？

# %%
from comparison_ui import launch_quality_comparison
quality_ui = launch_quality_comparison(preloader.soft_demo, preloader.hw_demo)
None  # 抑制自动输出

# %% [markdown]
# ---
#
# ## 1-4 静态评测 · 硬核效果放大镜
#
# 本节聚焦 **FPGA 硬核 ISP** 本身：
#
# - 展示 5 级流水线各级处理前后的静态效果
# - 结合 Gamma 曲线、亮度直方图，观察硬核对暗部、亮部的具体拉伸方式
# - 帮助理解"硬件版本的 ISP"内部在做什么

# %%
from comparison_ui import launch_hw_effect_demo
hw_effect_ui = launch_hw_effect_demo(preloader.soft_demo, preloader.hw_demo)
None  # 抑制自动输出

# %% [markdown]
# ---
#
# ## 1-5 静态评测 · 并行心电图
#
# 在不同模式、不同参数组合下重复测量 ISP 延时，观察 FPGA 硬核在像素级流水线下的"时间心电图"：
#
# - 理想情况下，处理时间几乎是一条水平线
# - 说明延时主要由分辨率决定，而与模式、参数无关

# %%
from comparison_ui import launch_parallel_advantage_demo
parallel_ui = launch_parallel_advantage_demo(preloader.soft_demo, preloader.hw_demo)
None  # 抑制自动输出

# %% [markdown]
# ---
#
# # 🎬 第二部分：视频导演区
#
# ---

# %% [markdown]
# ## 2-1 导演调色台 · 视频风格时间轴
#
# 通过关键帧设定和自动插值，创建"调色脚本"，实现视频风格的时间轴变化。

# %%
from grading_ui import launch_color_grading

# 启动导演调色台
grading_ui = launch_color_grading(
    hw_demo=preloader.hw_demo,
    preloaded_player=preloader.player
)
None  # 抑制自动输出

# %% [markdown]
# ---
#
# ## 2-2 视频跑分台 · 帧率与吞吐对对碰
#
# 对比 CPU 软核和 FPGA 硬核在视频处理上的帧率差异：CPU 只能当 PPT，FPGA 才是真实时。

# %%
from video_benchmark import launch_throughput_benchmark

# 运行帧率与吞吐量测试
benchmark_results = launch_throughput_benchmark(
    hw_demo=preloader.hw_demo,
    preloaded_player=preloader.player,
    test_frame_count=15
)
None  # 抑制输出

# %% [markdown]
# ---
#
# ## 2-3 并行实验室 · 让硬核帮软核瘦身
#
# 将 ISP 卸载到 FPGA 后，CPU 可以腾出资源做其他事情，展示软硬核协同的优势。

# %%
from video_benchmark import launch_cpu_usage_benchmark

# 获取 2-2 的 CPU FPS 结果
cpu_fps = benchmark_results.get('cpu_fps', 10.0) if benchmark_results else 10.0

# 运行 CPU 占用与并行能力测试
cpu_results = launch_cpu_usage_benchmark(
    hw_demo=preloader.hw_demo,
    preloaded_player=preloader.player,
    cpu_fps=cpu_fps
)
None  # 抑制输出

# %% [markdown]
# ---
#
# ## 2-4 AI 场记机 · 场景识别导演助理
#
# 轻量级神经网络实时识别场景，自动切换 ISP 模式，让 AI 当你的场记助理。

# %%
from scene_mlp_ui import launch_ai_scene_demo

# 启动 AI 场景识别演示
ai_demo = launch_ai_scene_demo(
    hw_demo=preloader.hw_demo,
    preloaded_player=preloader.player
)
None  # 抑制自动输出

# %% [markdown]
# <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#
# <!-- 演示完成卡片 -->
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 30px; border-radius: 20px; margin: 20px 0; text-align: center;">
#   <div style="font-size: 48px; margin-bottom: 10px;">🎬</div>
#   <div style="font-size: 28px; font-weight: 700; margin-bottom: 8px;">杀青 · 本次 ISP 影像试片到这里</div>
#   <div style="font-size: 14px; opacity: 0.9;">FPGA ISP 影像工作台 · PYNQ-Z2 软硬核协同</div>
# </div>
#
# <!-- 功能总结 -->
# <div style="background: #f8f9fa; border-radius: 16px; padding: 25px; margin: 15px 0;">
#   <div style="font-size: 18px; font-weight: 700; color: #2c3e50; margin-bottom: 20px; text-align: center;">📋 本次 Notebook 完成了两条线的展示</div>
#   <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(280px, 1fr)); gap: 15px;">
#     <div style="background: white; padding: 20px; border-radius: 12px; box-shadow: 0 2px 8px rgba(0,0,0,0.06); border-left: 4px solid #667eea;">
#       <div style="font-size: 16px; font-weight: 600; color: #667eea; margin-bottom: 10px;">📷 静态剧照区</div>
#       <div style="font-size: 13px; color: #666; line-height: 1.6;">
#         用 CPU 作为黄金参考，对比 FPGA 硬核的画质、时间和并行稳定性
#       </div>
#     </div>
#     <div style="background: white; padding: 20px; border-radius: 12px; box-shadow: 0 2px 8px rgba(0,0,0,0.06); border-left: 4px solid #e74c3c;">
#       <div style="font-size: 16px; font-weight: 600; color: #e74c3c; margin-bottom: 10px;">🎬 视频导演区</div>
#       <div style="font-size: 13px; color: #666; line-height: 1.6;">
#         通过调色时间轴、帧率跑分和 CPU 占用实验，展示软硬核协同的优势
#       </div>
#     </div>
#   </div>
#   <div style="margin-top: 20px; padding: 15px; background: linear-gradient(135deg, #27ae60 0%, #2ecc71 100%); color: white; border-radius: 10px; text-align: center; font-size: 14px; line-height: 1.8;">
#     💡 <b>核心结论</b>：静态图上，我们用 CPU 版本做黄金参考，证明 FPGA ISP 算法正确；<br>
#     视频上，我们用软硬核对比展示：只有把 ISP 放进 FPGA，才能在 720p@60fps 下既保证画质又释放 CPU，给后面的 AI / 协处理留空间。
#   </div>
# </div>
#
# <!-- 感谢信息 -->
# <div style="text-align: center; padding: 20px; color: #666;">
#   <div style="font-size: 14px;">感谢观看这场"小型 ISP 试映会" 🎬</div>
#   <div style="font-size: 12px; margin-top: 8px; opacity: 0.7;">队伍：让我们凡思逸下 · 编号：44646</div>
#   <div style="font-size: 11px; margin-top: 4px; opacity: 0.6;">后续可以在此基础上继续叠加神经网络等更智能的模块</div>
# </div>
#
# </div>
#
# ---
#
# <div style="font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#
# <!-- 附录标题 -->
# <div style="background: linear-gradient(135deg, #2c3e50 0%, #34495e 100%); color: white; padding: 20px 25px; border-radius: 16px; margin: 20px 0;">
#   <div style="font-size: 22px; font-weight: 700; margin-bottom: 10px;">📎 附录：硬件实现与资源占用概览</div>
#   <div style="font-size: 14px; line-height: 1.6; opacity: 0.95;">
#     本项目在 Zynq-7020 FPGA 上实现，以下为综合/实现后的资源占用和时序信息。
#   </div>
# </div>
#
# <!-- 基础信息 -->
# <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(200px, 1fr)); gap: 15px; margin: 15px 0;">
#   <div style="background: #e3f2fd; padding: 15px; border-radius: 10px; border-left: 4px solid #2196f3;">
#     <div style="font-weight: 700; color: #1565c0; font-size: 14px;">🎯 目标 FPGA</div>
#     <div style="font-size: 13px; color: #333; margin-top: 5px;">Zynq-7020 (xc7z020clg400-1)<br>PYNQ-Z2 开发板</div>
#   </div>
#   <div style="background: #fff3e0; padding: 15px; border-radius: 10px; border-left: 4px solid #ff9800;">
#     <div style="font-weight: 700; color: #e65100; font-size: 14px;">⏱️ 时钟频率</div>
#     <div style="font-size: 13px; color: #333; margin-top: 5px;">AXI: 100 MHz · 像素: 74.25 MHz<br>(720p@60Hz)</div>
#   </div>
#   <div style="background: #e8f5e9; padding: 15px; border-radius: 10px; border-left: 4px solid #4caf50;">
#     <div style="font-weight: 700; color: #2e7d32; font-size: 14px;">📺 输出分辨率</div>
#     <div style="font-size: 13px; color: #333; margin-top: 5px;">1280×720 · 24bpp RGB<br>60 Hz 刷新率</div>
#   </div>
# </div>
#
# <!-- 资源占用表格 -->
# <div style="background: white; border-radius: 12px; padding: 20px; margin: 15px 0; border: 1px solid #e9ecef;">
#   <div style="font-size: 16px; font-weight: 700; color: #2c3e50; margin-bottom: 15px;">📊 FPGA 资源占用 (v1.7 优化版)</div>
#   <table style="width: 100%; border-collapse: collapse; font-size: 13px;">
#     <thead>
#       <tr style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white;">
#         <th style="padding: 10px; text-align: left;">资源类型</th>
#         <th style="padding: 10px; text-align: center;">已用</th>
#         <th style="padding: 10px; text-align: center;">可用</th>
#         <th style="padding: 10px; text-align: center;">使用率</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr style="background: #f8f9fa;">
#         <td style="padding: 10px; border-bottom: 1px solid #eee;"><b>Slice LUTs</b></td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;">14,083</td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;">53,200</td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;"><span style="background:#27ae60; color:white; padding:2px 8px; border-radius:10px;">26.47%</span></td>
#       </tr>
#       <tr>
#         <td style="padding: 10px; border-bottom: 1px solid #eee;"><b>Slice Registers</b></td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;">18,543</td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;">106,400</td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;"><span style="background:#27ae60; color:white; padding:2px 8px; border-radius:10px;">17.43%</span></td>
#       </tr>
#       <tr style="background: #f8f9fa;">
#         <td style="padding: 10px; border-bottom: 1px solid #eee;"><b>Block RAM</b></td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;">17.5</td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;">140</td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;"><span style="background:#27ae60; color:white; padding:2px 8px; border-radius:10px;">12.50%</span></td>
#       </tr>
#       <tr>
#         <td style="padding: 10px; border-bottom: 1px solid #eee;"><b>DSP48E1</b></td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;">77</td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;">220</td>
#         <td style="padding: 10px; text-align: center; border-bottom: 1px solid #eee;"><span style="background:#27ae60; color:white; padding:2px 8px; border-radius:10px;">35.00%</span></td>
#       </tr>
#     </tbody>
#   </table>
#   <div style="font-size: 11px; color: #888; margin-top: 10px;">💡 v1.7 优化后资源显著降低：LUT -26%、FF -21%、BRAM -22%、DSP -41%</div>
# </div>
#
# <!-- 时序信息 -->
# <div style="display: flex; gap: 15px; margin: 15px 0; flex-wrap: wrap;">
#   <div style="flex: 1; min-width: 250px; background: linear-gradient(135deg, #27ae60 0%, #2ecc71 100%); color: white; padding: 20px; border-radius: 12px;">
#     <div style="font-size: 16px; font-weight: 700; margin-bottom: 10px;">⏱️ 时序分析</div>
#     <div style="font-size: 13px; line-height: 1.8;">
#       <div>✅ WNS: <b>0.780 ns</b></div>
#       <div>✅ WHS: <b>0.009 ns</b></div>
#       <div>✅ 所有约束: <b>PASS</b></div>
#     </div>
#   </div>
#   <div style="flex: 1; min-width: 250px; background: linear-gradient(135deg, #3498db 0%, #2980b9 100%); color: white; padding: 20px; border-radius: 12px;">
#     <div style="font-size: 16px; font-weight: 700; margin-bottom: 10px;">📁 生成文件</div>
#     <div style="font-size: 13px; line-height: 1.8; font-family: monospace;">
#       <div>📦 isp_hdmi_out.bit (4.05 MB)</div>
#       <div>📄 isp_hdmi_out.hwh (538 KB)</div>
#     </div>
#   </div>
# </div>
#
# </div>
